# %% [markdown]
# <a href="https://colab.research.google.com/github/lcipolina/escher/blob/Lucia/CNNescher.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **CNN to get the main features of the Escher painting**
#
# https://kharshit.github.io/blog/2018/12/14/filters-in-convolutional-neural-networks

# %% [markdown]
# # Imports

# %%
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense
from keras.preprocessing import image

# Commonly used modules
import numpy as np
import os
import sys

# Images, plots, display, and visualization
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import cv2
import IPython
from six.moves import urllib

print(tf.__version__)
# Out:
# Using TensorFlow backend.
# 2.2.0
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # Upload Image and Convert to Gray

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
import numpy as np

# Read in the image
# %cd /content/drive/My Drive/Colab Notebooks/Escher
img = mpimg.imread('painting.jpg')
plt.imshow(img)
# Out:
# /content/drive/My Drive/Colab Notebooks/Escher

# %%
# Convert to grayscale for filtering
# Tutorial: https://colab.research.google.com/drive/1RWGmqoEQdeyh5TssoGtsXsFk8hbLGtWp#scrollTo=yt5ww-mH0ASU

imgrgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(imgrgb)
plt.show()

# %%
#THIS IS A TEST DO NOT RUN
# Load image
img = cv2.imread('painting.jpg', 0)

# The underlying representation is a numpy array!
print(type(img))

plt.imshow(img)
plt.show()

#Convert to grayscale for filtering
img = cv2.imread('painting.jpg')
plt.imshow(img)
plt.show()

# %% [markdown]
# # Sobel Filter

# %%
# 3x3 sobel filter for horizontal edge detection
sobel_y = np.array([[ -1, -2, -1], 
                   [ 0, 0, 0], 
                   [ 1, 2, 1]])
# vertical edge detection
sobel_x = np.array([[-1, 0, 1],
                   [-2, 0, 2],
                   [-1, 0, 1]])
# filter the image using filter2D(grayscale image, bit-depth, kernel)  
filtered_image1 = cv2.filter2D(imgrgb, -1, sobel_x)
filtered_image2 = cv2.filter2D(imgrgb, -1, sobel_y)
f, ax = plt.subplots(1, 2, figsize=(15, 4))
ax[0].set_title('horizontal edge detection')
ax[0].imshow(filtered_image1, cmap='gray')
ax[1].set_title('vertical edge detection')
ax[1].imshow(filtered_image2, cmap='gray')
