# %% [markdown]
# <a href="https://colab.research.google.com/github/lcipolina/escher/blob/master/rotate_and_scale.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import the necessary packages
import numpy as np
import argparse
import imutils
import cv2
from google.colab.patches import cv2_imshow

# %%
#print current
# !pwd
# Out:
# /content

# %%
# upload files from disk
# load the file and change the name below on the 'fname' variable
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a3cab317-6d2c-4791-b6e9-4bd5294fe7a4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a3cab317-6d2c-4791-b6e9-4bd5294fe7a4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving escher_original.jpg to escher_original.jpg

# %%
# load the image from disk
fname = 'escher_original.jpg'
image = cv2.imread(fname)
# show image
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=450x450 at 0x7F4450ECEC88>

# %%
#https://www.pyimagesearch.com/2017/01/02/rotate-images-correctly-with-opencv-and-python/
#Rotate
angle = 157.62
#rotated = imutils.rotate(image, angle) #function that cuts corners
#cv2_imshow(rotated)
#ensure the entire image is bound inside the window and none is cut off.
rotated2 =imutils.rotate_bound(image, angle) #function that preserves the size
cv2_imshow(rotated2)
# Out:
# <PIL.Image.Image image mode=RGB size=587x587 at 0x7F4446DA4F98>

# %%
# Resize rotated image
scale_percent = 22.58
width = int(rotated2.shape[1] * scale_percent / 100)
height = int(rotated2.shape[0] * scale_percent / 100)
dim = (width, height)  
# resize image
resized = cv2.resize(rotated2, dim, interpolation = cv2.INTER_AREA)
cv2_imshow(resized)
# Out:
# <PIL.Image.Image image mode=RGB size=132x132 at 0x7F4446DB77B8>

# %%
#https://www.pyimagesearch.com/2017/01/02/rotate-images-correctly-with-opencv-and-python/
#detect edges
#image_filtered = cv2.Canny(image, 20, 100) #edges
image_filtered = cv2.Canny(image, 400, 550) #edges
cv2_imshow(image_filtered)
# Out:
# <PIL.Image.Image image mode=L size=450x450 at 0x7F446EADD9B0>
